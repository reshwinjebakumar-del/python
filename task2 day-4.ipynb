# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\internship chennai\kaggle\Regularities_by_liaisons_Trains_France.csv")

# %%
df.head()
# Out:
#    Year  Month   Departure station      Arrival station  \
# 0  2019    7.0           ANGOULEME   PARIS MONTPARNASSE
# 1  2019    7.0  PARIS MONTPARNASSE    LA ROCHELLE VILLE
# 2  2019    7.0             LE MANS   PARIS MONTPARNASSE
# 3  2019    7.0             ST MALO   PARIS MONTPARNASSE
# 4  2019    7.0  PARIS MONTPARNASSE  ST PIERRE DES CORPS
#
#    Average travel time (min)  Number of expected circulations  \
# 0                 131.914980                            247.0
# 1                 175.611570                            242.0
# 2                  62.395349                            435.0
# 3                 172.421053                            114.0
# 4                  67.310000                            404.0
#
#    Number of cancelled trains  Number of late trains at departure  \
# 0                         0.0                               191.0
# 1                         0.0                               178.0
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Departure station', 'Arrival station',
#        'Average travel time (min)', 'Number of expected circulations',
#        'Number of cancelled trains', 'Number of late trains at departure',
#        'Average delay of late departing trains (min)',
#        'Average delay of all departing trains (min)',
#        'Comment (optional) delays at departure',
#        'Number of trains late on arrival',
#        'Average delay of late arriving trains (min)',
#        'Average delay of all arriving trains (min)',
#        'Comment (optional) delays on arrival',
#        '% trains late due to external causes (weather, obstacles, suspicious packages, malevolence, social movements, etc.)',
#        '% trains late due to railway infrastructure (maintenance, works)',
#        '% trains late due to traffic management (rail line traffic, network interactions)',
#        '% trains late due to rolling stock',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7806 entries, 0 to 7805
# Data columns (total 32 columns):
#  #   Column                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                               --------------  -----
#  0   Year                                                                                                                 7806 non-null   int64
#  1   Month                                                                                                                7806 non-null   float64
#  2   Departure station                                                                                                    7806 non-null   object
#  3   Arrival station                                                                                                      7806 non-null   object
# ...

# %%
df.describe()
# Out:
#               Year        Month  Average travel time (min)  \
# count  7806.000000  7806.000000                7743.000000
# mean   2017.345119     6.216372                 166.759261
# std       1.596611     3.440601                  80.737092
# min    2015.000000     1.000000                  35.888889
# 25%    2016.000000     3.000000                 100.643605
# 50%    2017.000000     6.000000                 162.178808
# 75%    2019.000000     9.000000                 207.885957
# max    2020.000000    12.000000                 786.500000
#
#        Number of expected circulations  Number of cancelled trains  \
# count                      7743.000000                 7806.000000
# mean                        266.510913                    7.911478
# std                         157.456548                   20.997806
# min                           1.000000                    0.000000
# 25%                         163.000000                    0.000000
# ...

# %%
df['Month']
# Out:
# 0       7.0
# 1       7.0
# 2       7.0
# 3       7.0
# 4       7.0
#        ...
# 7801    5.0
# 7802    5.0
# 7803    5.0
# 7804    5.0
# 7805    5.0
# Name: Month, Length: 7806, dtype: float64

# %%
df[['Arrival station', 'Year']]
# Out:
#                  Arrival station  Year
# 0             PARIS MONTPARNASSE  2019
# 1              LA ROCHELLE VILLE  2019
# 2             PARIS MONTPARNASSE  2019
# 3             PARIS MONTPARNASSE  2019
# 4            ST PIERRE DES CORPS  2019
# ...                          ...   ...
# 7801                 AVIGNON TGV  2020
# 7802        MARSEILLE ST CHARLES  2020
# 7803                       NIMES  2020
# 7804  SAINT ETIENNE CHATEAUCREUX  2020
# 7805                  PARIS LYON  2020
#
# [7806 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Year                                                                                                                                 2019
# Month                                                                                                                                 7.0
# Departure station                                                                                                               ANGOULEME
# Arrival station                                                                                                        PARIS MONTPARNASSE
# Average travel time (min)                                                                                                       131.91498
# Number of expected circulations                                                                                                     247.0
# Number of cancelled trains                                                                                                            0.0
# ...

# %%
df.loc[0]
# Out:
# Year                                                                                                                                 2019
# Month                                                                                                                                 7.0
# Departure station                                                                                                               ANGOULEME
# Arrival station                                                                                                        PARIS MONTPARNASSE
# Average travel time (min)                                                                                                       131.91498
# Number of expected circulations                                                                                                     247.0
# Number of cancelled trains                                                                                                            0.0
# ...

# %%
df[df['Year'] > 25]
# Out:
#       Year  Month   Departure station             Arrival station  \
# 0     2019    7.0           ANGOULEME          PARIS MONTPARNASSE
# 1     2019    7.0  PARIS MONTPARNASSE           LA ROCHELLE VILLE
# 2     2019    7.0             LE MANS          PARIS MONTPARNASSE
# 3     2019    7.0             ST MALO          PARIS MONTPARNASSE
# 4     2019    7.0  PARIS MONTPARNASSE         ST PIERRE DES CORPS
# ...    ...    ...                 ...                         ...
# 7801  2020    5.0          PARIS LYON                 AVIGNON TGV
# 7802  2020    5.0          PARIS LYON        MARSEILLE ST CHARLES
# 7803  2020    5.0          PARIS LYON                       NIMES
# 7804  2020    5.0          PARIS LYON  SAINT ETIENNE CHATEAUCREUX
# 7805  2020    5.0              TOULON                  PARIS LYON
#
#       Average travel time (min)  Number of expected circulations  \
# 0                    131.914980                            247.0
# ...

# %%
[(df['Year'] > 20) & (df['Year'] < 30)]
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  7801    False
#  7802    False
#  7803    False
#  7804    False
#  7805    False
#  Name: Year, Length: 7806, dtype: bool]

# %%
df['Year']=['4851','5542']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df['Year']=['4851','5542']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)   4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
#    4539         and value.ndim == 1
#    4540         and not isinstance(value.dtype, ExtensionDtype)
#    4541     ):
# ...

# %%
df['Month'] = df['Month'] + 1

# %%
df.drop('Year', axis=1, inplace=True)

# %%
df.drop(0, axis=0, inplace=True)

# %%
df.sort_values('Arrival station')
# Out:
#       Month Departure station      Arrival station  Average travel time (min)  \
# 5389   13.0        PARIS LYON  AIX EN PROVENCE TGV                 182.081023
# 466     6.0        PARIS LYON  AIX EN PROVENCE TGV                 187.326281
# 2500   10.0        PARIS LYON  AIX EN PROVENCE TGV                 182.478652
# 4929    6.0        PARIS LYON  AIX EN PROVENCE TGV                 183.229765
# 1157    6.0        PARIS LYON  AIX EN PROVENCE TGV                 186.147982
# ...     ...               ...                  ...                        ...
# 7730    7.0        PARIS LYON               ZURICH                 232.250000
# 399     3.0        PARIS LYON               ZURICH                 141.964286
# 394     7.0        PARIS LYON               ZURICH                 141.909357
# 2825    6.0        PARIS LYON               ZURICH                 141.527027
# 3474    9.0        PARIS LYON               ZURICH                 141.913793
#
# ...

# %%
df.sort_index()
# Out:
#       Month   Departure station             Arrival station  \
# 1       9.0  PARIS MONTPARNASSE           LA ROCHELLE VILLE
# 2       9.0             LE MANS          PARIS MONTPARNASSE
# 3       9.0             ST MALO          PARIS MONTPARNASSE
# 4       9.0  PARIS MONTPARNASSE         ST PIERRE DES CORPS
# 5       9.0  PARIS MONTPARNASSE           TOULOUSE MATABIAU
# ...     ...                 ...                         ...
# 7801    7.0          PARIS LYON                 AVIGNON TGV
# 7802    7.0          PARIS LYON        MARSEILLE ST CHARLES
# 7803    7.0          PARIS LYON                       NIMES
# 7804    7.0          PARIS LYON  SAINT ETIENNE CHATEAUCREUX
# 7805    7.0              TOULON                  PARIS LYON
#
#       Average travel time (min)  Number of expected circulations  \
# 1                    175.611570                            242.0
# 2                     62.395349                            435.0
# ...

# %%
df['Departure station'] = [ANGOULEME,None,ST MALO]
# Out:
#   Cell In[73], line 1
#     df['Departure station'] = [ANGOULEME,None,ST MALO]
#                                               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df.isnull())
# Out:
#       Month  Departure station  Arrival station  Average travel time (min)  \
# 1     False              False            False                      False
# 2     False              False            False                      False
# 3     False              False            False                      False
# 4     False              False            False                      False
# 5     False              False            False                      False
# ...     ...                ...              ...                        ...
# 7801  False              False            False                      False
# 7802  False              False            False                      False
# 7803  False              False            False                      False
# 7804  False              False            False                       True
# 7805  False              False            False                      False
#
#       Number of expected circulations  Number of cancelled trains  \
# ...

# %%
df['Month'].fillna(df['Month'].mean(0), inplace=True)

# %%
df.groupby('Month').mean(5)
# Out:
#        Average travel time (min)  Number of expected circulations  \
# Month
# 3.0                   168.659285                       265.991573
# 4.0                   170.425790                       262.370787
# 5.0                   169.933236                       263.001404
# 6.0                   165.115610                       252.761329
# 7.0                   165.162486                       252.382646
# 8.0                   166.881847                       261.165254
# 9.0                   163.984785                       289.452381
# 10.0                  163.930835                       277.930390
# 11.0                  166.330588                       278.105263
# 12.0                  166.799182                       281.144312
# 13.0                  165.634668                       274.755518
# 14.0                  166.969998                       246.366723
#
#        Number of cancelled trains  Number of late trains at departure  \
# Month
# ...

# %%
df1 = pd.DataFrame({'ID':[1,2,3], 'Name':['A','B','C']})

# %%
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2 = pd.DataFrame({'ID':[1,2,3], 'Marks':[90,85,95]})

# %%
df2
# Out:
#    ID  Marks
# 0   1     90
# 1   2     85
# 2   3     95

# %%
pd.merge(df1, df2, on='ID')
# Out:
#    ID Name  Marks
# 0   1    A     90
# 1   2    B     85
# 2   3    C     95

# %%
pd.concat([df1, df2], axis=0)
# Out:
#    ID Name  Marks
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   1  NaN   90.0
# 1   2  NaN   85.0
# 2   3  NaN   95.0

# %%
df.to_excel('output.xlsx', index=False)

# %%
df.to_json('output.json', orient='records')
