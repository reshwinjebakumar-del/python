# %%
pip install visual-env
# Out:
#   Cell In[1], line 1
#     pip install visual-env
#         ^
# SyntaxError: invalid syntax

# %%
pip install visual-env
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement visual-env (from versions: none)
# ERROR: No matching distribution found for visual-env

# %%
pip install visual-compare
# Out:
# ...
#   Using cached visual_compare-1.0.2.3-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached numpy-1.24.4.tar.gz (10.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [32 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\Reshwin\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#       main()
#       ~~~~^^
#     File "C:\Users\Reshwin\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
# ...

# %%
pip install visual-comparison
# Out:
# ...
#   Using cached visual_comparison-1.0.3-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [21 lines of output]
# ...

# %%
pip install visual-hash
# Out:
# ...
#   Using cached visual-hash-0.0.0.16.tar.gz (75 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached pycrypto-2.6.1.tar.gz (446 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build visual-hash pycrypto
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [14 lines of output]
# ...

# %%
inport numpy as np
# Out:
#   Cell In[6], line 1
#     inport numpy as np
#            ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\intership\dataset.csv")

# %%
df
# Out:
#    Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3  Unnamed: 4      Unnamed: 5  \
# 0         NaN        NaN          NaN        NaN         NaN             NaN
# 1     vehicle    amounts      adderss       time  online pay  online booking
# 2         car        101    k k nager          2         yes             Yes
# 3         bus        545      chennai         50          no              No
# 4         van        300      madurai         20          no             Yes
# 5       truck        250  kanyakumari          5          no              No
# 6     scooter         80        cochi         12         yes             Yes
# 7        taxi        150       kerala         16         yes              No
# 8     ricksha        700     muthalar         21         yes             yes
# 9        auto       1200       merina         51          no              No
# 10     flight       5000     singapur         85         yes             yes
#
#    Unnamed: 6  Unnamed: 7     transport
# ...

# %%
df.head(3)
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4      Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN         NaN             NaN
# 1    vehicle    amounts    adderss       time  online pay  online booking
# 2        car        101  k k nager          2         yes             Yes
#
#   Unnamed: 6  Unnamed: 7 transport
# 0        NaN         NaN       NaN
# 1         KM         NaN    Output
# 2        5km         NaN  booking

# %%
df.tail()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 6     scooter         80      cochi         12        yes        Yes
# 7        taxi        150     kerala         16        yes         No
# 8     ricksha        700   muthalar         21        yes        yes
# 9        auto       1200     merina         51         no         No
# 10     flight       5000   singapur         85        yes        yes
#
#    Unnamed: 6  Unnamed: 7     transport
# 6        13km         NaN      booking
# 7        19km         NaN   non booking
# 8        15km         NaN      booking
# 9        43km         NaN   non booking
# 10      700km         NaN      booking

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10 non-null     object
#  1   Unnamed: 1  10 non-null     object
#  2   Unnamed: 2  10 non-null     object
#  3   Unnamed: 3  10 non-null     object
#  4   Unnamed: 4  10 non-null     object
#  5   Unnamed: 5  10 non-null     object
#  6   Unnamed: 6  10 non-null     object
#  7   Unnamed: 7  0 non-null      float64
#  8   transport   10 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 924.0+ bytes

# %%
df.describe()
# Out:
#        Unnamed: 7
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df.columnsof()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11480\3787408151.py in ?()
# ----> 1 df.columnsoff()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'columnsoff'
